# %%
# Task No 1
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Power")

opr = int(input("Choose operation (1-5): "))

if opr == 1:
    print("Result:", num1 + num2)
elif opr == 2:
    print("Result:", num1 - num2)
elif opr == 3:
    print("Result:", num1 * num2)
elif opr == 4:
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero")
elif opr == 5:
    print("Result:", num1 ** num2)
else:
    print("Kindly enter a number b/w 1-5")
# Out:
# Enter first number:  4
# Enter second number:  3
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Power
# Choose operation (1-5):  4
# Result: 1.3333333333333333

# %%
# Task No 2
myList = ["Muhammad", 30, "Ali", 3.14, "Mughal"]

for item in myList:
    if type(item) == int or type(item) == float:
        print("Numeric value found:", item)
# Out:
# Numeric value found: 30
# Numeric value found: 3.14

# %%
# Task No 3
myDict = {"name": "Hammad", "age": 23}

key = input("Enter new key: ")
value = input("Enter value: ")

myDict[key] = value

print("The dictionary has updated :", myDict)
# Out:
# Enter new key:  dept
# Enter value:  CS
# The dictionary has updated : {'name': 'Hammad', 'age': 23, 'dept': 'CS'}

# %%
# Task No 4
myDict2 = {"a": 20, "b": 40, "c": "Mirpurkhas", "d": 10}

total = 0

for value in myDict2.values():
    if isinstance(value, (int, float)):
        total += value

print("Sum of numeric values:", total)
# Out:
# Sum of numeric values: 70

# %%
# Task No 5
myList1 = [1, 2, 3, 2, 4, 5, 1, 6]

duplicates = []

for item in myList1:
    if myList1.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values:", duplicates)
# Out:
# Duplicate values: [1, 2]

# %%
# Task No 6
myDict3 = {"name": "Hammad", "age": 23}

key = input("Enter key to check: ")

if key in myDict3:
    print("Key exists in dictionary")
else:
    print("Key does not exist")
# Out:
# Enter key to check:  name
# Key exists in dictionary
